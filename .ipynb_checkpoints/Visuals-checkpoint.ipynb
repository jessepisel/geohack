# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib notebook

# %%
six = pd.read_csv(r'D:\geohack\ak_out\5002310015.csv')
seven = pd.read_csv(r'D:\geohack\ak_out\5002320001.csv')
eight = pd.read_csv(r'D:\geohack\ak_out\5002320002.csv')
nine = pd.read_csv(r'D:\geohack\ak_out\5002320003.csv')
unk = pd.read_csv(r'D:\geohack\ak_out\5002320004.csv')
biglake = pd.read_csv(r'D:\geohack\ak_out\5002320005.csv')

# %%
seven.head()
# Out:
#    Unnamed: 0   depth  sn       sp      ild      cild        dt  sn_top  \
# 0           0   999.0 NaN -20.5084   0.5451  196.2638       NaN     0.0
# 1           1   999.5 NaN -42.4613   0.5082  410.3642       NaN     0.0
# 2           2  1000.0 NaN -49.6482  11.6652  347.6305  168.9915     0.0
# 3           3  1000.5 NaN -52.7239  15.8829  213.8168  155.2572     0.0
# 4           4  1001.0 NaN -53.1664   3.0522  317.4550  138.2027     0.0
#
#    interval
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN

# %%
f, (ax1, ax2, ax3, ax4, ax5, ax6) = plt.subplots(1, 6, sharey=True)
ax1.plot(six.sn_top.values, six.depth.values*-1)
ax1.plot(six.ild.values, six.depth.values*-1)
ax1.set_title('Barrow 6')
ax1.set_ylabel('depth')
ax1.set_xlabel('OMM')

ax2.plot(seven.sn_top.values, seven.depth.values*-1)
ax2.plot(seven.ild.values, seven.depth.values*-1)
ax2.set_title('Barrow 7')
ax2.set_xlabel('OMM')

ax3.plot(eight.sn_top.values, eight.depth.values*-1)
ax3.plot(eight.ild.values, eight.depth.values*-1)
ax3.set_title('Barrow 8')
ax3.set_xlabel('OMM')


ax4.plot(nine.sn_top.values, nine.depth.values*-1)
ax4.plot(nine.ild.values, nine.depth.values*-1)
ax4.set_title('Barrow 9')
ax4.set_xlabel('OMM')

ax5.plot(unk.sn_top.values, unk.depth.values*-1)
ax5.plot(unk.ild.values, unk.depth.values*-1)
ax5.set_title('Barrow 10')
ax5.set_xlabel('OMM')

ax6.plot(biglake.sn_top.values, biglake.depth.values*-1)
ax6.plot(biglake.ild.values, biglake.depth.values*-1)
ax6.set_title('Big Lake 1')
ax6.set_xlabel('OMM')
# Out:
# <img src="data:image/png;base64,...">

# %%
plt.plot(data.sn_top.values, data.depth.values*-1)
plt.plot(data.ild.values, data.depth.values*-1)
plt.xlabel('Resistivity (OHMM)')
plt.ylabel('Depth (ft)')
plt.title('South Barrow 6 Well')
# Out:
# <img src="data:image/png;base64,...">
