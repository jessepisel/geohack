# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import lasio, glob
import missingno as msno
from pprint import pprint
# %matplotlib inline

# %%
path = r'F:\\Geology\\Undergraduate\\Research\\Raton Formation\\research_raton\\DONOTERASE\\Vermejo Park\\Western Wells\\'

# %%
allFiles=glob.glob(path+"*.las")

# %%
listed = []
for i in range(len(glob.glob(path+'*.*'))):
    listed.append(glob.glob(path+'*.*')[i][-4:])

# %%
tops=glob.glob(path+"*top*.*")
facies = glob.glob(path+'*facies*.*')

# %%
len(tops)
# Out:
# 0

# %%
for file in allFiles:
    logCurves=pd.DataFrame()

    l=lasio.read(file)
    for i in range(len(l.curves)):
        logCurves[l.curves[i].mnemonic] = l[l.curves[i].mnemonic]
logCurves
# Out:
#          DEPT     TT3    AMP3  CCL        GR
# 0     1178.25     NaN     NaN  NaN   78.5571
# 1     1178.50     NaN     NaN  NaN   89.5904
# 2     1178.75     NaN     NaN  NaN  100.1154
# 3     1179.00     NaN     NaN  NaN  108.6264
# 4     1179.25     NaN     NaN  NaN  114.8004
# 5     1179.50     NaN     NaN  NaN  119.6532
# 6     1179.75     NaN     NaN  NaN  124.7595
# 7     1180.00     NaN     NaN  NaN  130.8721
# 8     1180.25     NaN     NaN  NaN  137.2929
# 9     1180.50     NaN     NaN  NaN  142.6988
# 10    1180.75     NaN     NaN  NaN  146.2962
# 11    1181.00     NaN     NaN  NaN  147.9495
# 12    1181.25     NaN     NaN  NaN  147.5998
# 13    1181.50     NaN     NaN  NaN  145.0581
# 14    1181.75     NaN     NaN  NaN  140.3633
# 15    1182.00     NaN     NaN  NaN  134.1944
# 16    1182.25     NaN     NaN  NaN  127.9725
# 17    1182.50     NaN     NaN  NaN  123.5594
# 18    1182.75     NaN     NaN  NaN  122.4094
# 19    1183.00     NaN     NaN  NaN  124.5367
# ...

# %%
l.curves[1]['descr']
# Out:
# "CBL 3' Travel Time"

# %%
#step 1 is size of the dataset
if 51 < 50:
    print('Get More Data')
elif (len(tops) >= 0 | len(facies)>0) & len(allFiles)<100000:
    print('Linear SVC')
# Out:
# Linear SVC

# %%
len(allFiles)
# Out:
# 49
